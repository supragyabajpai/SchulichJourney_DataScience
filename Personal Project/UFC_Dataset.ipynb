# %% [markdown]
# UFC Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/supragyabajpai/SchulichJourney_DataScience/main/Personal%20Project/Datasets/data.csv")

# %%
df.head()
# Out:
#        R_fighter          B_fighter        Referee        date
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20  \
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#                  location Winner  title_bout       weight_class  B_avg_KD
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight     0.000  \
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight     0.500
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight       NaN
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight       NaN
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight     0.125
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO
# 0           0.0  ...                            0                1  \
# 1           0.0  ...                            0                3
# 2           NaN  ...                            1                3
# 3           NaN  ...                            0                0
# 4           0.0  ...                            1                2
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Stance  R_Height_cms
# 0                    0                             0  Orthodox        170.18  \
# 1                    0                             0  Orthodox        182.88
# 2                    0                             0  Southpaw        187.96
# 3                    0                             0    Switch        160.02
# 4                    2                             0  Orthodox        167.64
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       177.80         135.0   31.0   27.0
# 1       187.96         185.0   32.0   28.0
# 2       190.50         264.0   32.0   28.0
# 3       160.02         115.0   28.0   25.0
# 4       172.72         135.0   29.0   43.0
#
# [5 rows x 144 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6012 entries, 0 to 6011
# Columns: 144 entries, R_fighter to R_age
# dtypes: bool(1), float64(106), int64(28), object(9)
# memory usage: 6.6+ MB

# %%
df.describe(include ='all')
# Out:
#          R_fighter        B_fighter    Referee        date
# count         6012             6012       5980        6012  \
# unique        1514             1987        204         550
# top     Jim Miller  Jeremy Stephens  Herb Dean  2016-11-19
# freq            27               21        858          25
# mean           NaN              NaN        NaN         NaN
# std            NaN              NaN        NaN         NaN
# min            NaN              NaN        NaN         NaN
# 25%            NaN              NaN        NaN         NaN
# 50%            NaN              NaN        NaN         NaN
# 75%            NaN              NaN        NaN         NaN
# max            NaN              NaN        NaN         NaN
#
#                       location Winner title_bout weight_class     B_avg_KD
# count                     6012   6012       6012         6012  4585.000000  \
# unique                     166      3          2           14          NaN
# top     Las Vegas, Nevada, USA    Red      False  Lightweight          NaN
# freq                      1565   3979       5647         1091          NaN
# mean                       NaN    NaN        NaN          NaN     0.247476
# std                        NaN    NaN        NaN          NaN     0.378509
# min                        NaN    NaN        NaN          NaN     0.000000
# 25%                        NaN    NaN        NaN          NaN     0.000000
# 50%                        NaN    NaN        NaN          NaN     0.015625
# 75%                        NaN    NaN        NaN          NaN     0.500000
# max                        NaN    NaN        NaN          NaN     5.000000
#
#         B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO
# count    4585.000000  ...                  6012.000000      6012.000000  \
# unique           NaN  ...                          NaN              NaN
# top              NaN  ...                          NaN              NaN
# freq             NaN  ...                          NaN              NaN
# mean        0.176818  ...                     1.251331         1.297572
# std         0.324633  ...                     1.681376         1.859955
# min         0.000000  ...                     0.000000         0.000000
# 25%         0.000000  ...                     0.000000         0.000000
# 50%         0.000000  ...                     1.000000         1.000000
# 75%         0.250000  ...                     2.000000         2.000000
# max         3.000000  ...                    10.000000        11.000000
#
#         R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Stance
# count           6012.000000                   6012.000000      5983  \
# unique                  NaN                           NaN         5
# top                     NaN                           NaN  Orthodox
# freq                    NaN                           NaN      4538
# mean               0.796241                      0.069195       NaN
# std                1.355801                      0.273980       NaN
# min                0.000000                      0.000000       NaN
# 25%                0.000000                      0.000000       NaN
# 50%                0.000000                      0.000000       NaN
# 75%                1.000000                      0.000000       NaN
# max               13.000000                      2.000000       NaN
#
#         R_Height_cms  R_Reach_cms  R_Weight_lbs        B_age        R_age
# count    6008.000000  5606.000000   6010.000000  5840.000000  5949.000000
# unique           NaN          NaN           NaN          NaN          NaN
# top              NaN          NaN           NaN          NaN          NaN
# freq             NaN          NaN           NaN          NaN          NaN
# mean      178.991788   183.562347    170.686356    29.293151    29.598252
# std         8.812985    10.585313     35.724626     4.063297     4.167755
# min       152.400000   152.400000    115.000000    18.000000    19.000000
# 25%       172.720000   177.800000    145.000000    26.000000    27.000000
# 50%       180.340000   182.880000    170.000000    29.000000    29.000000
# 75%       185.420000   190.500000    185.000000    32.000000    32.000000
# max       210.820000   213.360000    345.000000    51.000000    47.000000
#
# [11 rows x 144 columns]
