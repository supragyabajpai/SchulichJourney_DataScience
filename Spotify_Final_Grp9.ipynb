# %% [markdown]
# <a href="https://colab.research.google.com/github/supragyabajpai/SchulichJourney_DataScience/blob/main/Spotify_Final_Grp9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Necessary Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from statsmodels.formula.api import ols
import statsmodels.api as sm
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, precision_recall_curve, mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')
from sklearn.cluster import KMeans

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path = '/content/drive/MyDrive/Schulich MBAN/Sem- 1/Data Science/FInal proect/spotify_data.csv'

# %%
df = pd.read_csv(dataset_path)

# %% [markdown]
# # Overview of Dataset

# %%
df.head()
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0429        0.6940          0.000000    0.1150    0.139  133.406
# 1       0.0258        0.4770          0.000014    0.0974    0.515  140.182
# 2       0.0323        0.3380          0.000050    0.0895    0.145  139.832
# 3       0.0363        0.8070          0.000000    0.0797    0.508  204.961
# 4       0.0302        0.0726          0.019300    0.1100    0.217  171.864
#
#    duration_ms  time_signature
# 0       240166               3
# 1       216387               4
# 2       158960               4
# 3       304293               4
# 4       244320               4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 20 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1159764 non-null  int64
#  1   artist_name       1159764 non-null  object
#  2   track_name        1159764 non-null  object
#  3   track_id          1159764 non-null  object
#  4   popularity        1159764 non-null  int64
#  5   year              1159764 non-null  int64
#  6   genre             1159764 non-null  object
#  7   danceability      1159764 non-null  float64
#  8   energy            1159764 non-null  float64
#  9   key               1159764 non-null  int64
#  10  loudness          1159764 non-null  float64
#  11  mode              1159764 non-null  int64
#  12  speechiness       1159764 non-null  float64
#  13  acousticness      1159764 non-null  float64
#  14  instrumentalness  1159764 non-null  float64
#  15  liveness          1159764 non-null  float64
#  16  valence           1159764 non-null  float64
#  17  tempo             1159764 non-null  float64
#  18  duration_ms       1159764 non-null  int64
#  19  time_signature    1159764 non-null  int64
# dtypes: float64(9), int64(7), object(4)
# memory usage: 177.0+ MB

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0  artist_name track_name                track_id  \
# count   1.159764e+06      1159764    1159764                 1159764
# unique           NaN        64159     882361                 1159764
# top              NaN  Traditional      Intro  53QF56cjZA9RTuuMZDrSA6
# freq             NaN         4058        466                       1
# mean    6.590613e+05          NaN        NaN                     NaN
# std     4.285492e+05          NaN        NaN                     NaN
# min     0.000000e+00          NaN        NaN                     NaN
# 25%     2.899408e+05          NaN        NaN                     NaN
# 50%     5.798815e+05          NaN        NaN                     NaN
# 75%     1.031689e+06          NaN        NaN                     NaN
# max     1.473395e+06          NaN        NaN                     NaN
#
#           popularity          year        genre  danceability        energy  \
# count   1.159764e+06  1.159764e+06      1159764  1.159764e+06  1.159764e+06
# unique           NaN           NaN           82           NaN           NaN
# top              NaN           NaN  black-metal           NaN           NaN
# freq             NaN           NaN        21852           NaN           NaN
# mean    1.838312e+01  2.011955e+03          NaN  5.374382e-01  6.396699e-01
# std     1.588554e+01  6.803901e+00          NaN  1.844780e-01  2.705009e-01
# min     0.000000e+00  2.000000e+03          NaN  0.000000e+00  0.000000e+00
# 25%     5.000000e+00  2.006000e+03          NaN  4.130000e-01  4.540000e-01
# 50%     1.500000e+01  2.012000e+03          NaN  5.500000e-01  6.940000e-01
# 75%     2.900000e+01  2.018000e+03          NaN  6.770000e-01  8.730000e-01
# max     1.000000e+02  2.023000e+03          NaN  9.930000e-01  1.000000e+00
#
#                  key      loudness          mode   speechiness  acousticness  \
# count   1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    5.287778e+00 -8.981353e+00  6.346533e-01  9.281477e-02  3.215370e-01
# std     3.555197e+00  5.682215e+00  4.815275e-01  1.268409e-01  3.549872e-01
# min     0.000000e+00 -5.810000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     2.000000e+00 -1.082900e+01  0.000000e+00  3.710000e-02  6.400000e-03
# 50%     5.000000e+00 -7.450000e+00  1.000000e+00  5.070000e-02  1.470000e-01
# 75%     8.000000e+00 -5.276000e+00  1.000000e+00  8.900000e-02  6.400000e-01
# max     1.100000e+01  6.172000e+00  1.000000e+00  9.710000e-01  9.960000e-01
#
#         instrumentalness      liveness       valence         tempo  \
# count       1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06
# unique               NaN           NaN           NaN           NaN
# top                  NaN           NaN           NaN           NaN
# freq                 NaN           NaN           NaN           NaN
# mean        2.523489e-01  2.230189e-01  4.555636e-01  1.213771e+02
# std         3.650731e-01  2.010707e-01  2.685190e-01  2.977975e+01
# min         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%         1.050000e-06  9.790000e-02  2.260000e-01  9.879700e+01
# 50%         1.760000e-03  1.340000e-01  4.380000e-01  1.219310e+02
# 75%         6.140000e-01  2.920000e-01  6.740000e-01  1.399030e+02
# max         1.000000e+00  1.000000e+00  1.000000e+00  2.499930e+02
#
#          duration_ms  time_signature
# count   1.159764e+06    1.159764e+06
# unique           NaN             NaN
# top              NaN             NaN
# freq             NaN             NaN
# mean    2.495618e+05    3.885879e+00
# std     1.494262e+05    4.676967e-01
# min     2.073000e+03    0.000000e+00
# 25%     1.810910e+05    4.000000e+00
# 50%     2.257440e+05    4.000000e+00
# 75%     2.869135e+05    4.000000e+00
# max     6.000495e+06    5.000000e+00

# %% [markdown]
# How many unique artists, song names, and genres are there?

# %%
print("Count of unique artist:",df['artist_name'].nunique())
print("Count of unique track_name:",df['track_name'].nunique())
print("Count of unique genre:",df['genre'].nunique())
# Out:
# Count of unique artist: 64159
# Count of unique track_name: 882361
# Count of unique genre: 82

# %% [markdown]
# We decided to drop all columns with unnamed values as unknown values would not help in the prediction process

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# We then created a correlation matrix to see which variables had the largest impact on popularity

# %%
corr_matrix = df.corr()

sorted_corr_popularity = corr_matrix['popularity'].sort_values(ascending=False)

# Plotting the heat map
plt.figure(figsize=(20, 12))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heat Map")
plt.show()

print("Sorted Correlation for 'popularity' column:")
print(sorted_corr_popularity)
# Out:
# Sorted Correlation for 'popularity' column:
# popularity          1.000000
# year                0.345821
# loudness            0.104097
# danceability        0.098533
# time_signature      0.030830
# energy              0.009401
# tempo               0.002566
# key                 0.000390
# valence            -0.018070
# mode               -0.023837
# speechiness        -0.024700
# liveness           -0.056968
# acousticness       -0.059181
# duration_ms        -0.118484
# instrumentalness   -0.152893
# Name: popularity, dtype: float64

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# We began began by creating some variables we believed would help predict popularity.
#
# This included ED Interaction which was the energy value of a song multiplied by its danceability, BPM ranges with categorized each songs bpm range into one of 4 categories (slow, medium, fast, rapid), IS ratio which is the instrumentalness of a song divided by its speachiness, and duration_mins which converted the duration in ms into minutes.

# %%
df['ED_Interaction'] = df['energy'] * df['danceability']

# %%
df['tempo'].describe()
# Out:
# count    1.159764e+06
# mean     1.213771e+02
# std      2.977975e+01
# min      0.000000e+00
# 25%      9.879700e+01
# 50%      1.219310e+02
# 75%      1.399030e+02
# max      2.499930e+02
# Name: tempo, dtype: float64

# %%
bpm_ranges = {
    'slow': (0, 99.910000),
    'medium': (99.910000, 122.107000),
    'fast': (122.107000, 139.990000),
    'rapid': (139.990000, 249.993000)
}

# %%
def categorize_bpm(tempo):
    for bpm_range, (min_bpm, max_bpm) in bpm_ranges.items():
        if min_bpm <= tempo < max_bpm:
            return bpm_range
    return 'unknown'

# %%
df['bpm_group'] = df['tempo'].apply(categorize_bpm)

# %%
df['IS_Ratio'] = df['instrumentalness']/ df['speechiness']

# %%
average_acousticness_by_genre = df.groupby('genre')['acousticness'].mean().reset_index()
average_acousticness_by_genre.rename(columns={'acousticness': 'average_acousticness'}, inplace=True)
df = df.merge(average_acousticness_by_genre, on='genre')

# %%
df_clustering = df.copy()

# %%
df['duration_mins'] = df['duration_ms'] / 60000

# %% [markdown]
# We then dropped the columns that we believed were no longer necessary. These were the track ID which we would use the track name to classify and duration_ms which had been converted to minutes.
#
# All years before 2018 were also dropped to keep only relevant data which was determined to be only data from the last 5 years.

# %%
df = df.drop(['track_id', 'duration_ms'], axis = 1)

# %%
df.drop(df[df['year'] <= 2018].index, inplace = True)

# %%
df.columns
# Out:
# Index(['artist_name', 'track_name', 'popularity', 'year', 'genre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'ED_Interaction', 'bpm_group', 'IS_Ratio',
#        'average_acousticness', 'duration_mins'],
#       dtype='object')

# %% [markdown]
# Visualized the data in order to see if there were any clear and obvious issues that needed to be addressed.
#
# The next section, outlier handling, deals with these issues we identified

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9), (ax10, ax11, ax12), (ax13, ax14 , _)) = plt.subplots(5, 3, figsize=(20, 25))

sns.histplot(df['danceability'], ax=ax1)
sns.histplot(df['energy'], ax=ax2)
sns.histplot(df['key'], ax=ax3)
sns.histplot(df['loudness'], ax=ax4)
sns.histplot(df['mode'], ax=ax5)
sns.histplot(df['speechiness'], ax=ax6)
sns.histplot(df['acousticness'], ax=ax7)
sns.histplot(df['instrumentalness'], ax=ax8)
sns.histplot(df['liveness'], ax=ax9)
sns.histplot(df['valence'], ax=ax10)
sns.histplot(df['tempo'], ax=ax11)
sns.histplot(df['duration_mins'], ax=ax12)
sns.histplot(df['time_signature'], ax=ax13)
sns.histplot(df['popularity'], ax =ax14)

plt.show()

# %% [markdown]
# # Outlier handeling

# %% [markdown]
# We decided to check how many values had no popularity value included. There were over 18,000 that did.
#
# We decided to drop these values as in a model where we are predicting popularity, we felt it made no sense to include such an overwhelming number of songs with no popularity value.

# %%
df[['popularity']].value_counts()
# Out:
# popularity
# 0             18273
# 28             5340
# 25             5206
# 27             5203
# 30             5201
#               ...
# 93                3
# 94                1
# 95                1
# 96                1
# 100               1
# Length: 98, dtype: int64

# %%
df.drop(df[df['popularity'] == 0].index, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238493 entries, 6629 to 1155057
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   artist_name           238493 non-null  object
#  1   track_name            238493 non-null  object
#  2   popularity            238493 non-null  int64
#  3   year                  238493 non-null  int64
#  4   genre                 238493 non-null  object
#  5   danceability          238493 non-null  float64
#  6   energy                238493 non-null  float64
#  7   key                   238493 non-null  int64
#  8   loudness              238493 non-null  float64
#  9   mode                  238493 non-null  int64
#  10  speechiness           238493 non-null  float64
#  11  acousticness          238493 non-null  float64
#  12  instrumentalness      238493 non-null  float64
#  13  liveness              238493 non-null  float64
#  14  valence               238493 non-null  float64
#  15  tempo                 238493 non-null  float64
#  16  time_signature        238493 non-null  int64
#  17  ED_Interaction        238493 non-null  float64
#  18  bpm_group             238493 non-null  object
#  19  IS_Ratio              238486 non-null  float64
#  20  average_acousticness  238493 non-null  float64
#  21  duration_mins         238493 non-null  float64
# dtypes: float64(13), int64(5), object(4)
# memory usage: 41.8+ MB

# %% [markdown]
# From the graph we identified a small amount of songs with 0 danceability, we just wanted to clarify if this was an issue or not and saw there were a lot of songs in this category. Therefore, we did not believe we had to remove them

# %%
df[df['danceability'] == 0]
# Out:
#                     artist_name  \
# 61694            Ólafur Arnalds
# 62114             Giya Kancheli
# 62325           Little Symphony
# 62455         Jóhann Jóhannsson
# 62464           Little Symphony
# ...                         ...
# 1064747   Ocean Waves For Sleep
# 1064762               Dog Music
# 1064767  White Noise Baby Sleep
# 1079464                  daste.
# 1090505                   Amaia
#
#                                                 track_name  popularity  year  \
# 61694                                saman (berlin) - live          30  2019
# 62114    33 Miniatures for Piano (Excerpts): No. 22, Gr...          54  2020
# 62325                                              Ringwil          37  2020
# 62455              Task No. 2: Communicating with the Past          36  2020
# 62464                                               Wailua          33  2020
# ...                                                    ...         ...   ...
# 1064747                                       Wave Therapy          12  2020
# 1064762                                  Feeling Sheltered          19  2020
# 1064767                                      Hushed Vacuum          23  2020
# 1079464                      Telephone (What's Your Name?)          54  2020
# 1090505                                         Última Vez          55  2019
#
#            genre  danceability    energy  key  loudness  mode  ...  \
# 61694    ambient           0.0  0.033100    3   -33.039     1  ...
# 62114    ambient           0.0  0.010700    5   -31.450     1  ...
# 62325    ambient           0.0  0.399000    2   -24.193     1  ...
# 62455    ambient           0.0  0.000654    2   -22.890     1  ...
# 62464    ambient           0.0  0.000971    0   -25.627     1  ...
# ...          ...           ...       ...  ...       ...   ...  ...
# 1064747    sleep           0.0  0.623000    1   -25.679     1  ...
# 1064762    sleep           0.0  0.032900    4   -27.179     1  ...
# 1064767    sleep           0.0  0.000020    6   -26.726     1  ...
# 1079464     soul           0.0  0.538000   10    -8.286     0  ...
# 1090505  spanish           0.0  0.005840    0   -16.798     1  ...
#
#          instrumentalness  liveness  valence  tempo  time_signature  \
# 61694             0.93900    0.1130      0.0    0.0               0
# 62114             0.94300    0.0750      0.0    0.0               0
# 62325             0.97300    0.2040      0.0    0.0               0
# 62455             0.80900    0.1090      0.0    0.0               0
# 62464             0.64000    0.1110      0.0    0.0               0
# ...                   ...       ...      ...    ...             ...
# 1064747           0.98500    0.1190      0.0    0.0               0
# 1064762           0.85800    0.1440      0.0    0.0               0
# 1064767           0.82800    0.6760      0.0    0.0               0
# 1079464           0.21300    0.0959      0.0    0.0               0
# 1090505           0.00692    0.1040      0.0    0.0               0
#
#          ED_Interaction  bpm_group  IS_Ratio average_acousticness  \
# 61694               0.0       slow       inf             0.728763
# 62114               0.0       slow       inf             0.728763
# 62325               0.0       slow       inf             0.728763
# 62455               0.0       slow       inf             0.728763
# 62464               0.0       slow       inf             0.728763
# ...                 ...        ...       ...                  ...
# 1064747             0.0       slow       inf             0.778803
# 1064762             0.0       slow       inf             0.778803
# 1064767             0.0       slow       inf             0.778803
# 1079464             0.0       slow       inf             0.321318
# 1090505             0.0       slow       inf             0.269187
#
#          duration_mins
# 61694         2.297467
# 62114         1.213550
# 62325         1.795600
# 62455         1.097533
# 62464         1.756250
# ...                ...
# 1064747       1.966667
# 1064762       1.586700
# 1064767       2.183333
# 1079464       2.883333
# 1090505       1.124533
#
# [189 rows x 22 columns]

# %% [markdown]
# We thought removing all songs with no spoken words would remove anything that could possibly not be a song

# %%
df['speechiness'].describe(include='all')
# Out:
# count    238493.000000
# mean          0.097213
# std           0.132218
# min           0.000000
# 25%           0.038000
# 50%           0.051800
# 75%           0.092900
# max           0.967000
# Name: speechiness, dtype: float64

# %%
df[df['speechiness'] == 0]
# Out:
#                     artist_name  \
# 61694            Ólafur Arnalds
# 62114             Giya Kancheli
# 62325           Little Symphony
# 62455         Jóhann Jóhannsson
# 62464           Little Symphony
# ...                         ...
# 1064747   Ocean Waves For Sleep
# 1064762               Dog Music
# 1064767  White Noise Baby Sleep
# 1079464                  daste.
# 1090505                   Amaia
#
#                                                 track_name  popularity  year  \
# 61694                                saman (berlin) - live          30  2019
# 62114    33 Miniatures for Piano (Excerpts): No. 22, Gr...          54  2020
# 62325                                              Ringwil          37  2020
# 62455              Task No. 2: Communicating with the Past          36  2020
# 62464                                               Wailua          33  2020
# ...                                                    ...         ...   ...
# 1064747                                       Wave Therapy          12  2020
# 1064762                                  Feeling Sheltered          19  2020
# 1064767                                      Hushed Vacuum          23  2020
# 1079464                      Telephone (What's Your Name?)          54  2020
# 1090505                                         Última Vez          55  2019
#
#            genre  danceability    energy  key  loudness  mode  ...  \
# 61694    ambient           0.0  0.033100    3   -33.039     1  ...
# 62114    ambient           0.0  0.010700    5   -31.450     1  ...
# 62325    ambient           0.0  0.399000    2   -24.193     1  ...
# 62455    ambient           0.0  0.000654    2   -22.890     1  ...
# 62464    ambient           0.0  0.000971    0   -25.627     1  ...
# ...          ...           ...       ...  ...       ...   ...  ...
# 1064747    sleep           0.0  0.623000    1   -25.679     1  ...
# 1064762    sleep           0.0  0.032900    4   -27.179     1  ...
# 1064767    sleep           0.0  0.000020    6   -26.726     1  ...
# 1079464     soul           0.0  0.538000   10    -8.286     0  ...
# 1090505  spanish           0.0  0.005840    0   -16.798     1  ...
#
#          instrumentalness  liveness  valence  tempo  time_signature  \
# 61694             0.93900    0.1130      0.0    0.0               0
# 62114             0.94300    0.0750      0.0    0.0               0
# 62325             0.97300    0.2040      0.0    0.0               0
# 62455             0.80900    0.1090      0.0    0.0               0
# 62464             0.64000    0.1110      0.0    0.0               0
# ...                   ...       ...      ...    ...             ...
# 1064747           0.98500    0.1190      0.0    0.0               0
# 1064762           0.85800    0.1440      0.0    0.0               0
# 1064767           0.82800    0.6760      0.0    0.0               0
# 1079464           0.21300    0.0959      0.0    0.0               0
# 1090505           0.00692    0.1040      0.0    0.0               0
#
#          ED_Interaction  bpm_group  IS_Ratio average_acousticness  \
# 61694               0.0       slow       inf             0.728763
# 62114               0.0       slow       inf             0.728763
# 62325               0.0       slow       inf             0.728763
# 62455               0.0       slow       inf             0.728763
# 62464               0.0       slow       inf             0.728763
# ...                 ...        ...       ...                  ...
# 1064747             0.0       slow       inf             0.778803
# 1064762             0.0       slow       inf             0.778803
# 1064767             0.0       slow       inf             0.778803
# 1079464             0.0       slow       inf             0.321318
# 1090505             0.0       slow       inf             0.269187
#
#          duration_mins
# 61694         2.297467
# 62114         1.213550
# 62325         1.795600
# 62455         1.097533
# 62464         1.756250
# ...                ...
# 1064747       1.966667
# 1064762       1.586700
# 1064767       2.183333
# 1079464       2.883333
# 1090505       1.124533
#
# [189 rows x 22 columns]

# %%
df.drop(df[df['speechiness'] == 0.000000].index, inplace = True)

# %% [markdown]
# What is the distribution of songs per genre?

# %%
sns.set(rc={"figure.figsize":(15, 6)})
ax=sns.histplot(data = df, x = "genre")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'acoustic'),
#  Text(1, 0, 'afrobeat'),
#  Text(2, 0, 'alt-rock'),
#  Text(3, 0, 'ambient'),
#  Text(4, 0, 'black-metal'),
#  Text(5, 0, 'blues'),
#  Text(6, 0, 'breakbeat'),
#  Text(7, 0, 'cantopop'),
#  Text(8, 0, 'chicago-house'),
#  Text(9, 0, 'chill'),
#  Text(10, 0, 'classical'),
#  Text(11, 0, 'club'),
#  Text(12, 0, 'comedy'),
#  Text(13, 0, 'country'),
#  Text(14, 0, 'dance'),
#  Text(15, 0, 'dancehall'),
#  Text(16, 0, 'death-metal'),
#  Text(17, 0, 'deep-house'),
#  Text(18, 0, 'detroit-techno'),
#  Text(19, 0, 'disco'),
#  Text(20, 0, 'drum-and-bass'),
#  Text(21, 0, 'dub'),
#  Text(22, 0, 'dubstep'),
#  Text(23, 0, 'edm'),
#  Text(24, 0, 'electro'),
#  Text(25, 0, 'electronic'),
#  Text(26, 0, 'emo'),
#  Text(27, 0, 'folk'),
#  Text(28, 0, 'forro'),
#  Text(29, 0, 'french'),
#  Text(30, 0, 'funk'),
#  Text(31, 0, 'garage'),
#  Text(32, 0, 'german'),
#  Text(33, 0, 'gospel'),
#  Text(34, 0, 'goth'),
#  Text(35, 0, 'grindcore'),
#  Text(36, 0, 'groove'),
#  Text(37, 0, 'guitar'),
#  Text(38, 0, 'hard-rock'),
#  Text(39, 0, 'hardcore'),
#  Text(40, 0, 'hardstyle'),
#  Text(41, 0, 'heavy-metal'),
#  Text(42, 0, 'hip-hop'),
#  Text(43, 0, 'house'),
#  Text(44, 0, 'indian'),
#  Text(45, 0, 'indie-pop'),
#  Text(46, 0, 'industrial'),
#  Text(47, 0, 'jazz'),
#  Text(48, 0, 'k-pop'),
#  Text(49, 0, 'metal'),
#  Text(50, 0, 'metalcore'),
#  Text(51, 0, 'minimal-techno'),
#  Text(52, 0, 'new-age'),
#  Text(53, 0, 'opera'),
#  Text(54, 0, 'party'),
#  Text(55, 0, 'piano'),
#  Text(56, 0, 'pop'),
#  Text(57, 0, 'pop-film'),
#  Text(58, 0, 'power-pop'),
#  Text(59, 0, 'progressive-house'),
#  Text(60, 0, 'psych-rock'),
#  Text(61, 0, 'punk'),
#  Text(62, 0, 'punk-rock'),
#  Text(63, 0, 'rock'),
#  Text(64, 0, 'rock-n-roll'),
#  Text(65, 0, 'romance'),
#  Text(66, 0, 'sad'),
#  Text(67, 0, 'salsa'),
#  Text(68, 0, 'samba'),
#  Text(69, 0, 'sertanejo'),
#  Text(70, 0, 'show-tunes'),
#  Text(71, 0, 'singer-songwriter'),
#  Text(72, 0, 'ska'),
#  Text(73, 0, 'sleep'),
#  Text(74, 0, 'songwriter'),
#  Text(75, 0, 'soul'),
#  Text(76, 0, 'spanish'),
#  Text(77, 0, 'swedish'),
#  Text(78, 0, 'tango'),
#  Text(79, 0, 'techno'),
#  Text(80, 0, 'trance'),
#  Text(81, 0, 'trip-hop')]

# %% [markdown]
# found that the songwriter genre only contained 5 songs and could interfere with further analysis if left in.

# %%
df[df['genre'] == 'songwriter']
# Out:
#                  artist_name               track_name  popularity  year  \
# 1075597            Lady Lamb            Untitled Soul          14  2019
# 1075598  Yusuf / Cat Stevens    Tea For The Tillerman          27  2020
# 1075599                JORDY  Dressed Up In A T-Shirt          23  2021
# 1075600         Jake Cornell         playing yourself          31  2022
# 1075601                   安溥         Miss missed Love          37  2022
#
#               genre  danceability  energy  key  loudness  mode  ...  \
# 1075597  songwriter         0.485   0.496    7    -6.394     1  ...
# 1075598  songwriter         0.466   0.286    0    -8.703     1  ...
# 1075599  songwriter         0.653   0.497    9    -9.172     1  ...
# 1075600  songwriter         0.680   0.488    0    -7.521     1  ...
# 1075601  songwriter         0.581   0.421    7   -11.319     0  ...
#
#          instrumentalness  liveness  valence    tempo  time_signature  \
# 1075597          0.000232    0.0794    0.239  115.892               3
# 1075598          0.000764    0.1910    0.599  211.315               4
# 1075599          0.000000    0.0993    0.783   79.906               4
# 1075600          0.000000    0.3940    0.688  148.017               4
# 1075601          0.000118    0.3410    0.348  116.911               4
#
#          ED_Interaction  bpm_group  IS_Ratio average_acousticness  \
# 1075597        0.240560     medium  0.007460             0.490719
# 1075598        0.133276      rapid  0.005832             0.490719
# 1075599        0.324541       slow  0.000000             0.490719
# 1075600        0.331840      rapid  0.000000             0.490719
# 1075601        0.244601     medium  0.004229             0.490719
#
#          duration_mins
# 1075597       4.624667
# 1075598       0.996667
# 1075599       2.526983
# 1075600       2.190367
# 1075601       3.113000
#
# [5 rows x 22 columns]

# %%
df.drop(df[df['genre'] == 'songwriter'].index, inplace = True)

# %%
sns.set(rc={"figure.figsize":(15, 6)})
ax=sns.histplot(df["genre"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'acoustic'),
#  Text(1, 0, 'afrobeat'),
#  Text(2, 0, 'alt-rock'),
#  Text(3, 0, 'ambient'),
#  Text(4, 0, 'black-metal'),
#  Text(5, 0, 'blues'),
#  Text(6, 0, 'breakbeat'),
#  Text(7, 0, 'cantopop'),
#  Text(8, 0, 'chicago-house'),
#  Text(9, 0, 'chill'),
#  Text(10, 0, 'classical'),
#  Text(11, 0, 'club'),
#  Text(12, 0, 'comedy'),
#  Text(13, 0, 'country'),
#  Text(14, 0, 'dance'),
#  Text(15, 0, 'dancehall'),
#  Text(16, 0, 'death-metal'),
#  Text(17, 0, 'deep-house'),
#  Text(18, 0, 'detroit-techno'),
#  Text(19, 0, 'disco'),
#  Text(20, 0, 'drum-and-bass'),
#  Text(21, 0, 'dub'),
#  Text(22, 0, 'dubstep'),
#  Text(23, 0, 'edm'),
#  Text(24, 0, 'electro'),
#  Text(25, 0, 'electronic'),
#  Text(26, 0, 'emo'),
#  Text(27, 0, 'folk'),
#  Text(28, 0, 'forro'),
#  Text(29, 0, 'french'),
#  Text(30, 0, 'funk'),
#  Text(31, 0, 'garage'),
#  Text(32, 0, 'german'),
#  Text(33, 0, 'gospel'),
#  Text(34, 0, 'goth'),
#  Text(35, 0, 'grindcore'),
#  Text(36, 0, 'groove'),
#  Text(37, 0, 'guitar'),
#  Text(38, 0, 'hard-rock'),
#  Text(39, 0, 'hardcore'),
#  Text(40, 0, 'hardstyle'),
#  Text(41, 0, 'heavy-metal'),
#  Text(42, 0, 'hip-hop'),
#  Text(43, 0, 'house'),
#  Text(44, 0, 'indian'),
#  Text(45, 0, 'indie-pop'),
#  Text(46, 0, 'industrial'),
#  Text(47, 0, 'jazz'),
#  Text(48, 0, 'k-pop'),
#  Text(49, 0, 'metal'),
#  Text(50, 0, 'metalcore'),
#  Text(51, 0, 'minimal-techno'),
#  Text(52, 0, 'new-age'),
#  Text(53, 0, 'opera'),
#  Text(54, 0, 'party'),
#  Text(55, 0, 'piano'),
#  Text(56, 0, 'pop'),
#  Text(57, 0, 'pop-film'),
#  Text(58, 0, 'power-pop'),
#  Text(59, 0, 'progressive-house'),
#  Text(60, 0, 'psych-rock'),
#  Text(61, 0, 'punk'),
#  Text(62, 0, 'punk-rock'),
#  Text(63, 0, 'rock'),
#  Text(64, 0, 'rock-n-roll'),
#  Text(65, 0, 'romance'),
#  Text(66, 0, 'sad'),
#  Text(67, 0, 'salsa'),
#  Text(68, 0, 'samba'),
#  Text(69, 0, 'sertanejo'),
#  Text(70, 0, 'show-tunes'),
#  Text(71, 0, 'singer-songwriter'),
#  Text(72, 0, 'ska'),
#  Text(73, 0, 'sleep'),
#  Text(74, 0, 'soul'),
#  Text(75, 0, 'spanish'),
#  Text(76, 0, 'swedish'),
#  Text(77, 0, 'tango'),
#  Text(78, 0, 'techno'),
#  Text(79, 0, 'trance'),
#  Text(80, 0, 'trip-hop')]

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9), (ax10, ax11, ax12), (ax13, ax14 , _)) = plt.subplots(5, 3, figsize=(20, 25))

sns.histplot(df['danceability'], ax=ax1)
sns.histplot(df['energy'], ax=ax2)
sns.histplot(df['key'], ax=ax3)
sns.histplot(df['loudness'], ax=ax4)
sns.histplot(df['mode'], ax=ax5)
sns.histplot(df['speechiness'], ax=ax6)
sns.histplot(df['acousticness'], ax=ax7)
sns.histplot(df['instrumentalness'], ax=ax8)
sns.histplot(df['liveness'], ax=ax9)
sns.histplot(df['valence'], ax=ax10)
sns.histplot(df['tempo'], ax=ax11)
sns.histplot(df['duration_mins'], ax=ax12)
sns.histplot(df['time_signature'], ax=ax13)
sns.histplot(df['popularity'], ax =ax14)

plt.show()

# %% [markdown]
# # Exploritory Data Analysis

# %% [markdown]
# How many songs are from each year?
#
# Understandibly there is less data for 2023 since the year is not over

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='year',color='green', bins = 5)
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %% [markdown]
# Which artists had the most songs?
#
# on first glance, the amount of songs an artist produces does not correlate to popularity as we were unaware of some of the artists on this list.

# %%
artist=df['artist_name'].value_counts()
artist=artist[:10,]
print(artist)
# Out:
# Elvis Presley            627
# SICK LEGEND              442
# Little Symphony          433
# Sleep Fruits Music       413
# Armin van Buuren         292
# Jim Brickman             285
# Johann Sebastian Bach    275
# Piano Peace              255
# Giuseppe Verdi           254
# Ludwig van Beethoven     253
# Name: artist_name, dtype: int64

# %% [markdown]
# Which songs were the most popular?
#
# Flowers was the most popular song with 100 popularity

# %%
popularity5=df.sort_values(by='popularity',ascending=False).head(10)
plt.figure(figsize=(20,4))
ac=sns.barplot(data=popularity5,x='track_name',y='popularity')
ac.set_xticklabels(ac.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Flowers'),
#  Text(1, 0, 'Shakira: Bzrp Music Sessions, Vol. 53'),
#  Text(2, 0, 'Die For You - Remix'),
#  Text(3, 0, 'Kill Bill'),
#  Text(4, 0, 'La Bachata'),
#  Text(5, 0, "I'm Good (Blue)"),
#  Text(6, 0, 'Calm Down (with Selena Gomez)'),
#  Text(7, 0, 'Unholy (feat. Kim Petras)'),
#  Text(8, 0, 'OMG'),
#  Text(9, 0, 'Quevedo: Bzrp Music Sessions, Vol. 52')]

# %% [markdown]
# Which songs had the most danceability?

# %%
df['danceability']=df['danceability']
df.sort_values(by='danceability',ascending =False,inplace=True)
dance=df.head(10)
plt.figure(figsize=(20,4))
ab=sns.barplot(x='track_name',y='danceability',data=dance)
ab.set_xticklabels(ab.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, "Slangin' Rocks"),
#  Text(1, 0, 'Botadinha Saliente'),
#  Text(2, 0, 'Conceited'),
#  Text(3, 0, 'I Hear The Music - Aki Bergen Dub-O-Matic Mix (Mixed)'),
#  Text(4, 0, 'Six Shots'),
#  Text(5, 0, 'U Got 2 - Original Mix'),
#  Text(6, 0, "This Isn't My Best Light"),
#  Text(7, 0, 'Marijuana, Malt Liquor'),
#  Text(8, 0, 'Widmo'),
#  Text(9, 0, 'The Game')]

# %% [markdown]
# Which genre of song was the loudest?

# %%
loudness_genreh=df.groupby('genre')['loudness'].mean().sort_values(ascending=False)
loudness_genreh=loudness_genreh[:10,]
plt.figure(figsize=(20,5))
sns.barplot(x=loudness_genreh.index,y=loudness_genreh.values)
plt.ylabel('avg loudness')
# Out:
# Text(0, 0.5, 'avg loudness')

# %% [markdown]
# Which genre of song was the least loud?

# %%
loudness_genrel=df.groupby('genre')['loudness'].mean().sort_values()
loudness_genrel=loudness_genrel[:10,]
plt.figure(figsize=(20,5))
sns.barplot(x=loudness_genrel.index,y=loudness_genrel.values)
plt.ylabel('avg loudness')
# Out:
# Text(0, 0.5, 'avg loudness')

# %% [markdown]
# Which genre of song has the most spoken words in it?

# %%
speech=df.groupby('genre')['speechiness'].mean().sort_values(ascending=False)
speech=speech[:5,]
plt.ylabel('avg speechiness')
sns.barplot(x=speech.index,y=speech.values)
# Out:
# <Axes: xlabel='genre', ylabel='avg speechiness'>

# %% [markdown]
# The comedy genre does actually include songs, the thought was this genre could include podcasts or comedy shows.

# %%
df_comedy = df[df['genre'] == 'comedy']
df_comedy.sort_values(by = 'popularity', ascending = False).head(10)
# Out:
#                 artist_name                         track_name  popularity  \
# 209210            Lil Dicky                              Earth          60
# 212106       Robin Williams   Friend Like Me - Remastered 2022          55
# 212107       Robin Williams       Prince Ali - Remastered 2022          52
# 212108         Martin Short                       Be Our Guest          47
# 210199              Afroman                          Crazy Rap          46
# 211172            Lil Dicky  We Good (From The TV Show "DAVE")          44
# 212109              Afroman                                420          44
# 209375  Kevin Bloody Wilson             Absolute Cunt of a Day          42
# 209211         Jim Gaffigan                        Travel Solo          37
# 211175           Louis C.K.        We All Had the Same Problem          37
#
#         year   genre  danceability  energy  key  loudness  mode  ...  \
# 209210  2019  comedy         0.694   0.664    2    -4.649     1  ...
# 212106  2022  comedy         0.620   0.506    2   -12.894     0  ...
# 212107  2022  comedy         0.516   0.435   10   -13.664     0  ...
# 212108  2022  comedy         0.486   0.512    0    -9.664     1  ...
# 210199  2020  comedy         0.925   0.371    9    -7.464     1  ...
# 211172  2021  comedy         0.652   0.574    7    -7.620     1  ...
# 212109  2022  comedy         0.848   0.482    1   -10.576     0  ...
# 209375  2019  comedy         0.532   0.821    9    -6.405     1  ...
# 209211  2019  comedy         0.672   0.778    1   -13.891     1  ...
# 211175  2021  comedy         0.455   0.842    7   -18.018     1  ...
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 209210            0.0000    0.0929   0.6760   95.941               4
# 212106            0.0000    0.5080   0.6320   98.582               4
# 212107            0.0000    0.1420   0.6300  105.707               4
# 212108            0.0000    0.1450   0.5820  125.376               4
# 210199            0.0000    0.1320   0.5270   99.013               4
# 211172            0.0000    0.1330   0.2990   80.996               4
# 212109            0.0021    0.1080   0.7820  120.008               4
# 209375            0.0000    0.8500   0.8040   78.783               4
# 209211            0.0000    0.6700   0.1650  122.182               4
# 211175            0.0000    0.8880   0.0972  107.158               3
#
#         ED_Interaction  bpm_group  IS_Ratio average_acousticness  \
# 209210        0.460816       slow  0.000000             0.735816
# 212106        0.313720       slow  0.000000             0.735816
# 212107        0.224460     medium  0.000000             0.735816
# 212108        0.248832       fast  0.000000             0.735816
# 210199        0.343175       slow  0.000000             0.735816
# 211172        0.374248       slow  0.000000             0.735816
# 212109        0.408736     medium  0.021694             0.735816
# 209375        0.436772       slow  0.000000             0.735816
# 209211        0.522816       fast  0.000000             0.735816
# 211175        0.383110     medium  0.000000             0.735816
#
#         duration_mins
# 209210       4.691667
# 212106       2.446217
# 212107       2.861333
# 212108       3.881333
# 210199       5.892783
# 211172       2.794600
# 212109       5.200983
# 209375       3.736667
# 209211       1.465800
# 211175       5.220900
#
# [10 rows x 22 columns]

# %% [markdown]
# Which genre has the least spoken words?

# %%
top_instrumentless=df.groupby('genre')['instrumentalness'].mean().sort_values(ascending=False)
top_instrumentless=top_instrumentless[:5,]
plt.ylabel('avg instrumentalness')
sns.barplot(x=top_instrumentless.index,y=top_instrumentless.values)
# Out:
# <Axes: xlabel='genre', ylabel='avg instrumentalness'>

# %% [markdown]
# Which genre has the highest value in the created variable ED interaction?

# %%
top_instrumentless=df.groupby('genre')['ED_Interaction'].mean().sort_values(ascending=False)
top_instrumentless=top_instrumentless[:5,]
sns.barplot(x=top_instrumentless.index,y=top_instrumentless.values)
# Out:
# <Axes: xlabel='genre'>

# %% [markdown]
# What is the distribution of values into the four categories created to classify BMP?

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='bpm_group',color='green', bins = 5)
# Out:
# <Axes: xlabel='bpm_group', ylabel='Count'>

# %% [markdown]
# What genres have the most songs and which have the least?

# %%
top_ten_genres = df['genre'].value_counts().nlargest(10).index.tolist()
bottom_ten_genres = df['genre'].value_counts().nsmallest(10).index.tolist()

# %%
print(top_ten_genres)
# Out:
# ['chill', 'black-metal', 'gospel', 'forro', 'emo', 'acoustic', 'deep-house', 'club', 'indian', 'ambient']

# %%
print(bottom_ten_genres)
# Out:
# ['romance', 'dubstep', 'house', 'detroit-techno', 'chicago-house', 'rock', 'tango', 'metalcore', 'pop', 'electro']

# %%
df['popularity'].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.tail(10)
# Out:
#                    artist_name                                   track_name  \
# 1066376     Sleep Fruits Music                           30 Min Brown Noise
# 65109         Ryuichi Sakamoto                                     20220202
# 1065212            Rain Sounds                           Heavy Pouring Rain
# 63748                       36  Take Me by the Hand (36 After Dark Version)
# 83804             Warmoon Lord                         Ancient Deaths Crown
# 1063562               Granular                            Brown Noise 68 hz
# 84517    A Thousand Sufferings                                       Stilte
# 807543   Rafael Anton Irisarri                                   Atrial 1.1
# 1063999     White Noise Babies                 Vaccum Cleaner Noise, Pt. 27
# 1065177          Linder Valley                          Polyrhythm Droplets
#
#          popularity  year        genre  danceability    energy  key  loudness  \
# 1066376          23  2022        sleep        0.0554  0.039700    1   -34.734
# 65109            36  2023      ambient        0.0554  0.001960    5   -26.971
# 1065212          23  2021        sleep        0.0554  0.992000    8   -12.673
# 63748            23  2021      ambient        0.0553  0.004580    1   -14.385
# 83804            17  2020  black-metal        0.0550  0.666000    4    -6.975
# 1063562          24  2019        sleep        0.0545  0.046900    1   -31.820
# 84517            20  2021  black-metal        0.0543  0.707000    8    -6.261
# 807543           12  2022      new-age        0.0542  0.000056    4   -14.074
# 1063999          44  2020        sleep        0.0534  0.033900    3   -16.455
# 1065177          33  2021        sleep        0.0469  0.044700   10   -50.769
#
#          mode  ...  instrumentalness  liveness  valence   tempo  \
# 1066376     1  ...             1.000    0.1120  0.01500  66.879
# 65109       1  ...             0.709    0.1010  0.03350  57.148
# 1065212     0  ...             0.979    0.8670  0.00001  55.939
# 63748       1  ...             0.872    0.1100  0.02970  59.104
# 83804       0  ...             0.910    0.2750  0.05790  55.692
# 1063562     0  ...             0.353    0.1110  0.02530  63.428
# 84517       1  ...             0.228    0.0964  0.10500  58.433
# 807543      1  ...             0.563    0.0998  0.03170  61.168
# 1063999     1  ...             0.985    0.4450  0.02480  48.647
# 1065177     0  ...             0.981    0.2020  0.19900  81.353
#
#          time_signature  ED_Interaction  bpm_group   IS_Ratio  \
# 1066376               4        0.002199       slow   5.649718
# 65109                 4        0.000109       slow  12.373473
# 1065212               4        0.054957       slow  14.271137
# 63748                 3        0.000253       slow  17.199211
# 83804                 4        0.036630       slow  11.787565
# 1063562               4        0.002556       slow   5.576619
# 84517                 4        0.038390       slow   2.593857
# 807543                4        0.000003       slow   2.857868
# 1063999               4        0.001810       slow  16.666667
# 1065177               3        0.002096       slow  16.350000
#
#         average_acousticness  duration_mins
# 1066376             0.778803      30.200000
# 65109               0.728763       6.375917
# 1065212             0.778803       3.566667
# 63748               0.728763       3.784850
# 83804               0.061433       5.458950
# 1063562             0.778803       2.898367
# 84517               0.061433       9.093567
# 807543              0.811769      10.250567
# 1063999             0.778803       1.387033
# 1065177             0.778803       2.452033
#
# [10 rows x 22 columns]

# %% [markdown]
# Categorized the popularity variable into two categories. If it has a popularity of 50 and above then it is classified as popular, if not it is categorized as low. We tried this with 40 but believed too many of the songs were considered popular with this threshold. Making the cutoff 50 makes it so only songs with popularity in the top 10 percent are categorized as popular.

# %%
pop40plus = df[df['popularity'] >= 40].shape[0]
print("Number of values with popularity 40+: ", pop40plus)

pop40less = df[df['popularity'] < 40].shape[0]
print("Number of values with popularity <40: ", pop40less)
# Out:
# Number of values with popularity 40+:  62162
# Number of values with popularity <40:  176137

# %%
pop50plus = df[df['popularity'] >= 50].shape[0]
print("Number of values with popularity 50+: ", pop50plus)

pop50less = df[df['popularity'] < 50].shape[0]
print("Number of values with popularity <50: ", pop50less)
# Out:
# Number of values with popularity 50+:  27232
# Number of values with popularity <50:  211067

# %%
percent40 = (pop40plus / (pop40plus + pop40less))*100
print('Percent of songs with popularity over 40: ', percent40)

percent50 = (pop50plus / (pop50plus + pop50less))*100
print('Percent of songs with popularity over 50: ', percent50)
# Out:
# Percent of songs with popularity over 40:  26.08571584438038
# Percent of songs with popularity over 50:  11.427660208393657

# %%
for i, row in df.iterrows():
  score = 'low'
  if row.popularity >=50:
    score = 'popular'
  df.at[i, 'popular'] = score

# %%
columns = df[['year', 'danceability', 'energy', 'key', 'loudness', 'mode',
              'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_mins', 'time_signature',
              'ED_Interaction', 'bpm_group', 'IS_Ratio', 'average_acousticness']]

# %% [markdown]
# Created the X variable with only numberic variables from the columns list above
#
# Set y equal to popular which is our target variable

# %%
X = columns.select_dtypes(include='number')
y = df['popular']

# %%
X.head()
# Out:
#         year  danceability  energy  key  loudness  mode  speechiness  \
# 211001  2020         0.986   0.351    6   -10.660     1       0.2260
# 484260  2022         0.985   0.698    0    -2.531     1       0.0341
# 247092  2022         0.984   0.719    8    -5.119     1       0.0893
# 148211  2020         0.984   0.551    8    -9.187     0       0.2850
# 302279  2022         0.984   0.887   11    -4.309     0       0.1970
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 211001       0.00378          0.000000    0.0898    0.357  114.984
# 484260       0.14200          0.000000    0.3210    0.914  119.959
# 247092       0.05660          0.000099    0.5170    0.437  118.015
# 148211       0.00113          0.006640    0.3050    0.272  123.979
# 302279       0.01340          0.003360    0.7770    0.896  126.011
#
#         duration_mins  time_signature  ED_Interaction  IS_Ratio  \
# 211001       3.780433               4        0.346086  0.000000
# 484260       2.633333               4        0.687530  0.000000
# 247092       2.447583               4        0.707496  0.001106
# 148211       4.948167               4        0.542184  0.023298
# 302279       3.174600               4        0.872808  0.017056
#
#         average_acousticness
# 211001              0.735816
# 484260              0.222015
# 247092              0.131716
# 148211              0.032253
# 302279              0.055158

# %%
df.columns
# Out:
# Index(['artist_name', 'track_name', 'popularity', 'year', 'genre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'ED_Interaction', 'bpm_group', 'IS_Ratio',
#        'average_acousticness', 'duration_mins', 'popular'],
#       dtype='object')

# %%
all_columns = df[['artist_name', 'track_name', 'popularity', 'year', 'genre', 'danceability', 'energy', 'key', 'loudness', 'mode',
              'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_mins', 'time_signature',
              'ED_Interaction', 'bpm_group', 'IS_Ratio', 'average_acousticness']]

# %% [markdown]
# Created an ordinary least squares regression model.
#
# This model aided in backwards elimination meaning that variables where the P value was less than 0.05 were removed. Key and time signature were removed for this reason.

# %%
results = ols("popularity ~ genre + mode + year + IS_Ratio + year + danceability + energy + loudness + mode + speechiness + acousticness + instrumentalness + liveness + valence + tempo + duration_mins", data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             popularity   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.582
# Method:                 Least Squares   F-statistic:                     3567.
# Date:                Mon, 07 Aug 2023   Prob (F-statistic):               0.00
# Time:                        00:18:26   Log-Likelihood:            -9.0071e+05
# No. Observations:              238299   AIC:                         1.802e+06
# Df Residuals:                  238205   BIC:                         1.803e+06
# Df Model:                          93
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   -442.9520     32.773    -13.516      0.000    -507.186    -378.718
# genre[T.afrobeat]            -13.6285      0.263    -51.916      0.000     -14.143     -13.114
# genre[T.alt-rock]             14.4549      0.239     60.380      0.000      13.986      14.924
# genre[T.ambient]               8.6852      0.243     35.767      0.000       8.209       9.161
# genre[T.black-metal]          -8.3924      0.245    -34.295      0.000      -8.872      -7.913
# genre[T.blues]                -1.9067      0.238     -8.021      0.000      -2.373      -1.441
# genre[T.breakbeat]           -18.0179      0.318    -56.708      0.000     -18.641     -17.395
# genre[T.cantopop]             -8.3973      0.263    -31.984      0.000      -8.912      -7.883
# genre[T.chicago-house]       -17.8063      0.424    -42.018      0.000     -18.637     -16.976
# genre[T.chill]                16.6268      0.228     72.767      0.000      16.179      17.075
# genre[T.classical]             9.4587      0.264     35.883      0.000       8.942       9.975
# genre[T.club]                 -5.7330      0.238    -24.091      0.000      -6.199      -5.267
# genre[T.comedy]              -14.8934      0.313    -47.615      0.000     -15.506     -14.280
# genre[T.country]              18.4547      0.244     75.762      0.000      17.977      18.932
# genre[T.dance]                26.9301      0.249    108.042      0.000      26.442      27.419
# genre[T.dancehall]            -1.5614      0.240     -6.505      0.000      -2.032      -1.091
# genre[T.death-metal]          -1.8231      0.252     -7.224      0.000      -2.318      -1.328
# genre[T.deep-house]            6.0452      0.240     25.199      0.000       5.575       6.515
# genre[T.detroit-techno]      -18.4903      0.471    -39.286      0.000     -19.413     -17.568
# genre[T.disco]                -0.2314      0.262     -0.883      0.377      -0.745       0.282
# genre[T.drum-and-bass]        -7.3869      0.260    -28.383      0.000      -7.897      -6.877
# genre[T.dub]                   1.6122      0.241      6.698      0.000       1.140       2.084
# genre[T.dubstep]             -10.4288      0.640    -16.293      0.000     -11.683      -9.174
# genre[T.edm]                  18.3386      0.303     60.558      0.000      17.745      18.932
# genre[T.electro]              21.9877      0.321     68.514      0.000      21.359      22.617
# genre[T.electronic]            8.5587      0.271     31.561      0.000       8.027       9.090
# genre[T.emo]                   7.6611      0.235     32.604      0.000       7.201       8.122
# genre[T.folk]                 12.9781      0.243     53.458      0.000      12.502      13.454
# genre[T.forro]                -4.7844      0.237    -20.206      0.000      -5.248      -4.320
# genre[T.french]               14.9551      0.244     61.295      0.000      14.477      15.433
# genre[T.funk]                 10.4682      0.248     42.255      0.000       9.983      10.954
# genre[T.garage]               -1.0653      0.244     -4.362      0.000      -1.544      -0.587
# genre[T.german]               10.0170      0.252     39.777      0.000       9.523      10.511
# genre[T.gospel]               -2.5192      0.232    -10.879      0.000      -2.973      -2.065
# genre[T.goth]                -11.0749      0.250    -44.321      0.000     -11.565     -10.585
# genre[T.grindcore]           -19.3627      0.330    -58.729      0.000     -20.009     -18.717
# genre[T.groove]               -3.9622      0.291    -13.616      0.000      -4.533      -3.392
# genre[T.guitar]               -4.0856      0.277    -14.763      0.000      -4.628      -3.543
# genre[T.hard-rock]            -2.6081      0.262     -9.960      0.000      -3.121      -2.095
# genre[T.hardcore]              3.3784      0.254     13.299      0.000       2.880       3.876
# genre[T.hardstyle]            -0.3207      0.243     -1.320      0.187      -0.797       0.155
# genre[T.heavy-metal]         -16.8049      0.300    -55.986      0.000     -17.393     -16.217
# genre[T.hip-hop]              28.1415      0.249    113.086      0.000      27.654      28.629
# genre[T.house]                22.7570      0.484     47.047      0.000      21.809      23.705
# genre[T.indian]               -4.9463      0.233    -21.245      0.000      -5.403      -4.490
# genre[T.indie-pop]            23.1062      0.270     85.624      0.000      22.577      23.635
# genre[T.industrial]          -11.5237      0.249    -46.368      0.000     -12.011     -11.037
# genre[T.jazz]                 13.0212      0.237     54.906      0.000      12.556      13.486
# genre[T.k-pop]                16.9081      0.238     71.017      0.000      16.441      17.375
# genre[T.metal]                15.9089      0.305     52.207      0.000      15.312      16.506
# genre[T.metalcore]            -3.5931      0.337    -10.661      0.000      -4.254      -2.933
# genre[T.minimal-techno]       -8.2234      0.257    -31.969      0.000      -8.728      -7.719
# genre[T.new-age]             -11.3997      0.246    -46.272      0.000     -11.883     -10.917
# genre[T.opera]               -13.4525      0.268    -50.228      0.000     -13.977     -12.928
# genre[T.party]               -10.2780      0.287    -35.868      0.000     -10.840      -9.716
# genre[T.piano]                10.7146      0.252     42.564      0.000      10.221      11.208
# genre[T.pop]                  37.8307      0.328    115.187      0.000      37.187      38.474
# genre[T.pop-film]             -0.6225      0.249     -2.502      0.012      -1.110      -0.135
# genre[T.power-pop]           -17.5496      0.266    -66.057      0.000     -18.070     -17.029
# genre[T.progressive-house]     5.7088      0.265     21.524      0.000       5.189       6.229
# genre[T.psych-rock]           -4.5895      0.264    -17.365      0.000      -5.107      -4.071
# genre[T.punk]                  8.9385      0.323     27.650      0.000       8.305       9.572
# genre[T.punk-rock]            -4.7651      0.302    -15.786      0.000      -5.357      -4.174
# genre[T.rock]                 22.3245      0.411     54.258      0.000      21.518      23.131
# genre[T.rock-n-roll]         -16.5841      0.256    -64.763      0.000     -17.086     -16.082
# genre[T.romance]             -24.3031      0.775    -31.350      0.000     -25.822     -22.784
# genre[T.sad]                  16.7540      0.248     67.435      0.000      16.267      17.241
# genre[T.salsa]               -10.8489      0.247    -43.874      0.000     -11.334     -10.364
# genre[T.samba]               -10.8954      0.247    -44.198      0.000     -11.379     -10.412
# genre[T.sertanejo]             6.6252      0.247     26.868      0.000       6.142       7.108
# genre[T.show-tunes]          -11.1230      0.286    -38.867      0.000     -11.684     -10.562
# genre[T.singer-songwriter]     8.0177      0.248     32.373      0.000       7.532       8.503
# genre[T.ska]                 -12.0648      0.252    -47.786      0.000     -12.560     -11.570
# genre[T.sleep]                11.0168      0.274     40.158      0.000      10.479      11.554
# genre[T.soul]                 15.5242      0.281     55.194      0.000      14.973      16.076
# genre[T.spanish]               5.7862      0.238     24.311      0.000       5.320       6.253
# genre[T.swedish]               5.8238      0.270     21.584      0.000       5.295       6.353
# genre[T.tango]               -22.0406      0.338    -65.262      0.000     -22.703     -21.379
# genre[T.techno]                2.8720      0.294      9.784      0.000       2.297       3.447
# genre[T.trance]                0.7206      0.296      2.436      0.015       0.141       1.300
# genre[T.trip-hop]            -12.4527      0.284    -43.883      0.000     -13.009     -11.897
# mode                          -0.5731      0.046    -12.496      0.000      -0.663      -0.483
# year                           0.2339      0.016     14.423      0.000       0.202       0.266
# IS_Ratio                       0.0676      0.007      9.730      0.000       0.054       0.081
# danceability                   4.6609      0.179     26.027      0.000       4.310       5.012
# energy                        -1.2003      0.188     -6.379      0.000      -1.569      -0.831
# loudness                       0.2234      0.008     27.007      0.000       0.207       0.240
# speechiness                   -1.7804      0.267     -6.675      0.000      -2.303      -1.258
# acousticness                   0.5411      0.117      4.644      0.000       0.313       0.769
# instrumentalness              -4.7273      0.163    -29.004      0.000      -5.047      -4.408
# liveness                      -1.4894      0.129    -11.513      0.000      -1.743      -1.236
# valence                       -1.8832      0.117    -16.164      0.000      -2.112      -1.655
# tempo                          0.0087      0.001     11.042      0.000       0.007       0.010
# duration_mins                 -0.3629      0.013    -28.730      0.000      -0.388      -0.338
# ==============================================================================
# Omnibus:                    11561.122   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20757.190
# Skew:                           0.386   Prob(JB):                         0.00
# Kurtosis:                       4.223   Cond. No.                     3.06e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.06e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pred_vals = results.predict(df[['ED_Interaction', 'IS_Ratio', 'year', 'genre', 'danceability', 'energy', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_mins']])

# %%
res = pd.concat([pred_vals.to_frame().rename(columns={0:'y_hat'}),df['popularity']], axis=1)

# %%
res['error'] = res['y_hat'] - res['popularity']

# %%
res['sq_error'] = res['error']**2

# %%
RMSE = np.sqrt(res['sq_error'].mean())
print("RMSE:", RMSE)
# Out:
# RMSE: 10.599320626222681

# %% [markdown]
# Begin splitting the data in train and test sets in order to use in the following models

# %%
cat_columns = ['genre', 'mode', 'year']
num_columns = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness',
               'liveness', 'valence', 'tempo', 'duration_mins']
target = 'popularity'

# %%
X_train, X_test, y_train, y_test = train_test_split(df[cat_columns + num_columns], df[target], test_size=0.2, random_state=42)

# %%
cat_transformer = Pipeline(steps = [('onehot', OneHotEncoder(handle_unknown='ignore'))])
num_transformer = Pipeline(steps = [('scaler', StandardScaler())])
preprocessor = ColumnTransformer(transformers = [('cat',cat_transformer, cat_columns),
                                                 ('num', num_transformer, num_columns)])

# %% [markdown]
# # Linear Regression

# %%
linear_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
linear_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['genre', 'mode', 'year']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['danceability', 'energy',
#                                                    'loudness', 'speechiness',
#                                                    'acousticness',
#                                                    'instrumentalness',
#                                                    'liveness', 'valence',
#                                                    'tempo',
#                                                    'duration_mins'])])),
#                 ('regressor', LinearRegression())])

# %%
pred = linear_regression.predict(X_test)

# %%
RMSE = np.sqrt(mean_squared_error(pred, y_test))
print('RMSE:' ,RMSE)

r2 = r2_score(y_test, pred)
print("R-squared value:", r2)
# Out:
# RMSE: 10.3330131263947
# R-squared value: 0.6043587327320029

# %% [markdown]
# # Ridge Regression

# %%
ridge_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Ridge(alpha=3.0))
])

# %%
ridge_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['genre', 'mode', 'year']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['danceability', 'energy',
#                                                    'loudness', 'speechiness',
#                                                    'acousticness',
#                                                    'instrumentalness',
#                                                    'liveness', 'valence',
#                                                    'tempo',
#                                                    'duration_mins'])])),
#                 ('regressor', Ridge(alpha=3.0))])

# %%
pred_ridge = ridge_regression.predict(X_test)

# %%
RMSE = np.sqrt(mean_squared_error(pred_ridge, y_test))
print('RMSE:' ,RMSE)

r2 = r2_score(y_test, pred_ridge)
print("R-squared value:", r2)
# Out:
# RMSE: 10.333024234540542
# R-squared value: 0.604357882090819

# %% [markdown]
# # Lasso Ridge

# %%
lasso_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Lasso(alpha=1.0))
])

# %%
lasso_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['genre', 'mode', 'year']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['danceability', 'energy',
#                                                    'loudness', 'speechiness',
#                                                    'acousticness',
#                                                    'instrumentalness',
#                                                    'liveness', 'valence',
#                                                    'tempo',
#                                                    'duration_mins'])])),
#                 ('regressor', Lasso())])

# %%
lasso_pred = lasso_regression.predict(X_test)

# %%
RMSE = np.sqrt(mean_squared_error(lasso_pred, y_test))
print('RMSE:', RMSE)

r2 = r2_score(y_test, lasso_pred)
print("R-squared value:", r2)
# Out:
# RMSE: 15.845888358522783
# R-squared value: 0.06957621138115033

# %% [markdown]
# # Elastic Net

# %%
elasticnet_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', ElasticNet(alpha=1.0, l1_ratio=0.8))
])

# %%
elasticnet_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['genre', 'mode', 'year']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['danceability', 'energy',
#                                                    'loudness', 'speechiness',
#                                                    'acousticness',
#                                                    'instrumentalness',
#                                                    'liveness', 'valence',
#                                                    'tempo',
#                                                    'duration_mins'])])),
#                 ('regressor', ElasticNet(l1_ratio=0.8))])

# %%
elasticnet_pred = elasticnet_regression.predict(X_test)

# %%
RMSE = np.sqrt(mean_squared_error(elasticnet_pred, y_test))
print('RMSE', RMSE)

r2 = r2_score(y_test, elasticnet_pred)
print("R-squared value:", r2)
# Out:
# RMSE 15.835450773479817
# R-squared value: 0.07080153605705874

# %% [markdown]
# We tried to increase the accuracy of the Logistic Regression model through the use of different solver and increasing the max_iter. The max percentage that could be achieved was 88.65%.

# %% [markdown]
# # Logstic Regression

# %%
scaler = StandardScaler()
model_X = scaler.fit(X)
X_scaled = model_X.transform(X)

X_train, X_test, y_train, y_test = train_test_split (X_scaled, y, random_state=42, test_size=0.3, shuffle=True)

# %%
from sklearn import datasets, linear_model, metrics

log_reg = linear_model.LogisticRegression(solver = 'newton-cg', max_iter=10000)
log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)

# %%
print("Logistic Regression Model Accuracy (in %):",
metrics.accuracy_score(y_test, y_pred) * 100)
# Out:
# Logistic Regression Model Accuracy (in %): 88.64736326758987

# %% [markdown]
# # K Nearest Neighbour

# %% [markdown]
# This model yielded a percentage of 82.58% which was the lowest of all the models so we decided to leave it and attempt to improve others.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# %%
print("KNN Model Accuracy (in %):",
metrics.accuracy_score(y_test, pred) * 100)
# Out:
# KNN Model Accuracy (in %): 82.57658413764163

# %% [markdown]
# # Decision Tree

# %% [markdown]
# This model achieved a percentage of around 88% but we believed it could be improved to an accuracy higher than the random forest model. We would prefer to use decision tree to avoid over fitting and it requires less computational power.
#
# To improve the model we changed the max depth and was able to achieve a model accuracy of %90.92 with a max_depth of 8.

# %%
d_tree = DecisionTreeClassifier(random_state=42, max_depth=8)
d_tree.fit(X_train, y_train)
y_pred = d_tree.predict(X_test)

# %%
print("Decsision Tree Model Accuracy (in %):",
metrics.accuracy_score(y_test, y_pred) * 100)
# Out:
# Decsision Tree Model Accuracy (in %): 90.91900965169954

# %% [markdown]
# # Random Forest

# %% [markdown]
# The random forest initially had the highest model accuracy. However, after hyper parameter tuning, we were able to achieve a higher accuracy in the decision tree model. This model also takes more time and computational power to compute.

# %%
rforest = RandomForestClassifier(n_estimators = 200)
rforest.fit(X_train, y_train)
y_pred = rforest.predict(X_test)

# %%
print("Random Forest Model Accuracy (in %):",
metrics.accuracy_score(y_test, y_pred) * 100)
# Out:
# Random Forest Model Accuracy (in %): 90.64484543292768

# %% [markdown]
# # Playlist Generator

# %%
df_clustering.head()
# Out:
#      artist_name        track_name                track_id  popularity  year  \
# 0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6          68  2012
# 1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218          50  2012
# 2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F          57  2012
# 3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz          58  2012
# 4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8          54  2012
#
#       genre  danceability  energy  key  loudness  ...  instrumentalness  \
# 0  acoustic         0.483   0.303    4   -10.058  ...          0.000000
# 1  acoustic         0.572   0.454    3   -10.286  ...          0.000014
# 2  acoustic         0.409   0.234    3   -13.711  ...          0.000050
# 3  acoustic         0.392   0.251   10    -9.845  ...          0.000000
# 4  acoustic         0.430   0.791    6    -5.419  ...          0.019300
#
#    liveness  valence    tempo  duration_ms  time_signature  ED_Interaction  \
# 0    0.1150    0.139  133.406       240166               3        0.146349
# 1    0.0974    0.515  140.182       216387               4        0.259688
# 2    0.0895    0.145  139.832       158960               4        0.095706
# 3    0.0797    0.508  204.961       304293               4        0.098392
# 4    0.1100    0.217  171.864       244320               4        0.340130
#
#    bpm_group  IS_Ratio  average_acousticness
# 0       fast  0.000000              0.574223
# 1      rapid  0.000531              0.574223
# 2       fast  0.001548              0.574223
# 3      rapid  0.000000              0.574223
# 4      rapid  0.639073              0.574223
#
# [5 rows x 23 columns]

# %% [markdown]
# We will exclude the songs from before the year 2012 to keep the song recomendations from the last 10 years of songs

# %%
df_clustering.drop(df_clustering[df_clustering['year'] < 2012].index, inplace = True)

# %%
df_clustering.columns
# Out:
# Index(['artist_name', 'track_name', 'track_id', 'popularity', 'year', 'genre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature', 'ED_Interaction', 'bpm_group',
#        'IS_Ratio', 'average_acousticness'],
#       dtype='object')

# %% [markdown]
# While observing the ordinary least squares model it was concluded that key, mode, and time_signature had no significance to the outcome.
#
# For energy, danceability, and tempo, new variables were created and these values were not needed anymore.

# %%
columns_to_drop = ['key','mode','liveness','time_signature','energy','danceability','tempo']
df_clustering.drop(columns=columns_to_drop, inplace=True)

# %%
df_clustering.columns
# Out:
# Index(['artist_name', 'track_name', 'track_id', 'popularity', 'year', 'genre',
#        'loudness', 'speechiness', 'acousticness', 'instrumentalness',
#        'valence', 'duration_ms', 'ED_Interaction', 'bpm_group', 'IS_Ratio',
#        'average_acousticness'],
#       dtype='object')

# %%
bpm_onehot = pd.get_dummies(df_clustering['bpm_group'], prefix='bpm',dtype=int)
df_clustering = pd.concat([df_clustering, bpm_onehot], axis=1)
df_clustering.drop(columns=['bpm_group'], inplace=True)

# %%
df_clustering.columns
# Out:
# Index(['artist_name', 'track_name', 'track_id', 'popularity', 'year', 'genre',
#        'loudness', 'speechiness', 'acousticness', 'instrumentalness',
#        'valence', 'duration_ms', 'ED_Interaction', 'IS_Ratio',
#        'average_acousticness', 'bpm_fast', 'bpm_medium', 'bpm_rapid',
#        'bpm_slow'],
#       dtype='object')

# %%
df_clustering.head()
# Out:
#      artist_name        track_name                track_id  popularity  year  \
# 0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6          68  2012
# 1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218          50  2012
# 2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F          57  2012
# 3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz          58  2012
# 4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8          54  2012
#
#       genre  loudness  speechiness  acousticness  instrumentalness  valence  \
# 0  acoustic   -10.058       0.0429        0.6940          0.000000    0.139
# 1  acoustic   -10.286       0.0258        0.4770          0.000014    0.515
# 2  acoustic   -13.711       0.0323        0.3380          0.000050    0.145
# 3  acoustic    -9.845       0.0363        0.8070          0.000000    0.508
# 4  acoustic    -5.419       0.0302        0.0726          0.019300    0.217
#
#    duration_ms  ED_Interaction  IS_Ratio  average_acousticness  bpm_fast  \
# 0       240166        0.146349  0.000000              0.574223         1
# 1       216387        0.259688  0.000531              0.574223         0
# 2       158960        0.095706  0.001548              0.574223         1
# 3       304293        0.098392  0.000000              0.574223         0
# 4       244320        0.340130  0.639073              0.574223         0
#
#    bpm_medium  bpm_rapid  bpm_slow
# 0           0          0         0
# 1           0          1         0
# 2           0          0         0
# 3           0          1         0
# 4           0          1         0

# %%
df_clustering.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 622651 entries, 0 to 1155058
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   artist_name           622651 non-null  object
#  1   track_name            622651 non-null  object
#  2   track_id              622651 non-null  object
#  3   popularity            622651 non-null  int64
#  4   year                  622651 non-null  int64
#  5   genre                 622651 non-null  object
#  6   loudness              622651 non-null  float64
#  7   speechiness           622651 non-null  float64
#  8   acousticness          622651 non-null  float64
#  9   instrumentalness      622651 non-null  float64
#  10  valence               622651 non-null  float64
#  11  duration_ms           622651 non-null  int64
#  12  ED_Interaction        622651 non-null  float64
#  13  IS_Ratio              622590 non-null  float64
#  14  average_acousticness  622651 non-null  float64
#  15  bpm_fast              622651 non-null  int64
#  16  bpm_medium            622651 non-null  int64
#  17  bpm_rapid             622651 non-null  int64
#  18  bpm_slow              622651 non-null  int64
# dtypes: float64(8), int64(7), object(4)
# memory usage: 95.0+ MB

# %% [markdown]
# We will apply data scaling prior to creating clusters.

# %%
columns_for_scaling = ['loudness', 'speechiness', 'acousticness', 'instrumentalness',
                       'valence', 'duration_ms', 'ED_Interaction',
                       'average_acousticness', 'bpm_fast', 'bpm_medium', 'bpm_rapid',
                       'bpm_slow']
scaler = StandardScaler()
data = scaler.fit_transform(df_clustering[columns_for_scaling])
scaled_df = pd.DataFrame(data=data, columns=columns_for_scaling)

# %%
scaled_df.head()
# Out:
#    loudness  speechiness  acousticness  instrumentalness   valence  \
# 0 -0.220533    -0.401187      1.075595         -0.693296 -1.112053
# 1 -0.259948    -0.531378      0.460353         -0.693258  0.315275
# 2 -0.852032    -0.481890      0.066258         -0.693160 -1.089277
# 3 -0.183712    -0.451436      1.395975         -0.693296  0.288702
# 4  0.581417    -0.497879     -0.686209         -0.640715 -0.815958
#
#    duration_ms  ED_Interaction  average_acousticness  bpm_fast  bpm_medium  \
# 0     0.012212       -1.134051              1.010543  1.745347   -0.580835
# 1    -0.168216       -0.522715              1.010543 -0.572952   -0.580835
# 2    -0.603954       -1.407213              1.010543  1.745347   -0.580835
# 3     0.498787       -1.392725              1.010543 -0.572952   -0.580835
# 4     0.043731       -0.088821              1.010543 -0.572952   -0.580835
#
#    bpm_rapid  bpm_slow
# 0  -0.577672 -0.577942
# 1   1.731085 -0.577942
# 2  -0.577672 -0.577942
# 3   1.731085 -0.577942
# 4   1.731085 -0.577942

# %%
scaled_df.columns
# Out:
# Index(['loudness', 'speechiness', 'acousticness', 'instrumentalness',
#        'valence', 'duration_ms', 'ED_Interaction', 'average_acousticness',
#        'bpm_fast', 'bpm_medium', 'bpm_rapid', 'bpm_slow'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

# %%
# Using the elbow method to find the optimal number of clusters
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)
    print("Epoch : ", i)
    print('-----------')
# Out:
# Epoch :  1
# -----------
# Epoch :  2
# -----------
# Epoch :  3
# -----------
# Epoch :  4
# -----------
# Epoch :  5
# -----------
# Epoch :  6
# -----------
# Epoch :  7
# -----------
# Epoch :  8
# -----------
# Epoch :  9
# -----------
# Epoch :  10
# -----------
# Epoch :  11
# -----------
# Epoch :  12
# -----------
# Epoch :  13
# -----------
# Epoch :  14
# -----------
# Epoch :  15
# -----------
# Epoch :  16
# -----------
# Epoch :  17
# -----------
# Epoch :  18
# -----------
# Epoch :  19
# -----------

# %%
plt.plot(range(1, 20), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# Based on the above graph, we have concluded that the elbow is forming at the point corresponding to 12.

# %%
n_clusters = 12
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(scaled_df)

# %%
df_clustering['Cluster'] = cluster_labels

# %%
df_clustering.head()
# Out:
#      artist_name        track_name                track_id  popularity  year  \
# 0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6          68  2012
# 1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218          50  2012
# 2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F          57  2012
# 3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz          58  2012
# 4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8          54  2012
#
#       genre  loudness  speechiness  acousticness  instrumentalness  valence  \
# 0  acoustic   -10.058       0.0429        0.6940          0.000000    0.139
# 1  acoustic   -10.286       0.0258        0.4770          0.000014    0.515
# 2  acoustic   -13.711       0.0323        0.3380          0.000050    0.145
# 3  acoustic    -9.845       0.0363        0.8070          0.000000    0.508
# 4  acoustic    -5.419       0.0302        0.0726          0.019300    0.217
#
#    duration_ms  ED_Interaction  IS_Ratio  average_acousticness  bpm_fast  \
# 0       240166        0.146349  0.000000              0.574223         1
# 1       216387        0.259688  0.000531              0.574223         0
# 2       158960        0.095706  0.001548              0.574223         1
# 3       304293        0.098392  0.000000              0.574223         0
# 4       244320        0.340130  0.639073              0.574223         0
#
#    bpm_medium  bpm_rapid  bpm_slow  Cluster
# 0           0          0         0        3
# 1           0          1         0       11
# 2           0          0         0        3
# 3           0          1         0       11
# 4           0          1         0       11

# %%
cluster_sizes = df_clustering['Cluster'].value_counts()

sorted_cluster_sizes = dict(sorted(cluster_sizes.items()))
for cluster_label, size in sorted_cluster_sizes.items():
    print(f"Cluster {cluster_label}: {size} data points")
# Out:
# Cluster 0: 113775 data points
# Cluster 1: 40476 data points
# Cluster 2: 78505 data points
# Cluster 3: 28892 data points
# Cluster 4: 76236 data points
# Cluster 5: 44133 data points
# Cluster 6: 42524 data points
# Cluster 7: 10892 data points
# Cluster 8: 81458 data points
# Cluster 9: 610 data points
# Cluster 10: 37615 data points
# Cluster 11: 67535 data points

# %% [markdown]
# We can see the cluster size of each cluster.

# %% [markdown]
# # Making Playlist

# %%
def get_similar_popular_tracks(track_name, df_clustering):
    input_track_cluster = df_clustering.loc[df_clustering["track_name"] == track_name, "Cluster"].values[0]
    input_track_popularity = df_clustering.loc[df_clustering["track_name"] == track_name, "popularity"].values[0]

    recommended_tracks = df_clustering[
        (df_clustering["Cluster"] == input_track_cluster) &
        (df_clustering["popularity"] > input_track_popularity)
    ]

    recommended_tracks = recommended_tracks.sort_values(by="popularity", ascending=False)

    recommended_track_names = recommended_tracks["track_name"].head(10).tolist()

    return recommended_track_names

# %% [markdown]
# By executing the following code and inputting a track name from the data, we can generate a playlist containing ten songs from the same cluster as the input track, with each song having a popularity greater than that of the input track.

# %%
input_track_name = input("Enter the track name: ")

recommended_tracks = get_similar_popular_tracks(input_track_name, df_clustering)

print("Recommended Tracks:")
for idx, track_name in enumerate(recommended_tracks, 1):
    print(f"{idx}. {track_name}")
# Out:
# Enter the track name: I Won't Give Up
# Recommended Tracks:
# 1. Here With Me
# 2. Romantic Homicide
# 3. Midnight Rain
# 4. LIMBO
# 5. we fell in love in october
# 6. you broke me first
# 7. YKWIM?
# 8. Collide (feat. Tyga)
# 9. 5 Regras - Ao Vivo
# 10. rises the moon
